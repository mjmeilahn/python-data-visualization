# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# %matplotlib inline

currentDir = os.getcwd()
stats = pd.read_csv(currentDir + '/Demographic-Data.csv')

# Always a good idea to record how many rows are imported
# for traceability and keeping an active record ...
# as some rows may be corrupted or later discarded.

# rows = len(stats)
# cols = len(stats.columns)

# %%
# Top 5 Rows
stats.head() # To change amount put any number as an argument
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Bottom 5 Rows
stats.tail() # To change amount put any number as argument
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# General Info on Columns
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
# Basic analysis of numbers in CSV
# stats.describe()

# Same as above but displays results horizontally
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
# Re-name columns
stats.columns = ['Country', 'Code', 'Birth Rate', 'Internet', 'Income']
stats.head()
# Out:
#                 Country Code  Birth Rate  Internet               Income
# 0                 Aruba  ABW      10.244      78.9          High income
# 1           Afghanistan  AFG      35.253       5.9           Low income
# 2                Angola  AGO      45.985      19.1  Upper middle income
# 3               Albania  ALB      12.877      57.2  Upper middle income
# 4  United Arab Emirates  ARE      11.044      88.0          High income

# %%
# Slice out Rows 21 - 25.
stats[21:26]

# You can also do other slices from the beginning or end.
# beginning -- stats[:5] or the end -- stats[20:]
# Out:
#      Country Code  Birth Rate  Internet               Income
# 21    Belize  BLZ      23.092     33.60  Upper middle income
# 22   Bermuda  BMU      10.400     95.30          High income
# 23   Bolivia  BOL      24.236     36.94  Lower middle income
# 24    Brazil  BRA      14.931     51.04  Upper middle income
# 25  Barbados  BRB      12.188     73.00          High income

# %%
# Reverse the Rows
stats[::-1]
# Out:
#                             Country Code  Birth Rate  Internet  \
# 194                        Zimbabwe  ZWE      35.715  18.50000
# 193                          Zambia  ZMB      40.471  15.40000
# 192                Congo, Dem. Rep.  COD      42.394   2.20000
# 191                    South Africa  ZAF      20.850  46.50000
# 190                     Yemen, Rep.  YEM      32.947  20.00000
# 189                           Samoa  WSM      26.172  15.30000
# 188              West Bank and Gaza  PSE      30.394  46.60000
# 187                         Vanuatu  VUT      26.739  11.30000
# 186                         Vietnam  VNM      15.537  43.90000
# 185           Virgin Islands (U.S.)  VIR      10.700  45.30000
# 184                   Venezuela, RB  VEN      19.842  54.90000
# 183  St. Vincent and the Grenadines  VCT      16.306  52.00000
# 182                      Uzbekistan  UZB      22.500  38.20000
# 181                   United States  USA      12.500  84.20000
# ...

# %%
# Get every 20th country
stats[::20]
# Out:
#         Country Code  Birth Rate  Internet               Income
# 0         Aruba  ABW      10.244   78.9000          High income
# 20      Belarus  BLR      12.500   54.1700  Upper middle income
# 40   Costa Rica  CRI      15.022   45.9600  Upper middle income
# 60        Gabon  GAB      30.555    9.2000  Upper middle income
# 80        India  IND      20.291   15.1000  Lower middle income
# 100       Libya  LBY      21.425   16.5000  Upper middle income
# 120  Mozambique  MOZ      39.705    5.4000           Low income
# 140      Poland  POL       9.600   62.8492          High income
# 160    Suriname  SUR      18.455   37.4000  Upper middle income
# 180     Uruguay  URY      14.374   57.6900          High income

# %%
# Extract a column
stats['Country'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: Country, dtype: object

# %%
# Extract two or more columns
stats[['Country', 'Birth Rate']].head()
# Out:
#                 Country  Birth Rate
# 0                 Aruba      10.244
# 1           Afghanistan      35.253
# 2                Angola      45.985
# 3               Albania      12.877
# 4  United Arab Emirates      11.044

# %%
# Subset of Rows & Columns Example
stats[5:11][['Country', 'Birth Rate']]
# Out:
#                 Country  Birth Rate
# 5             Argentina      17.716
# 6               Armenia      13.308
# 7   Antigua and Barbuda      16.447
# 8             Australia      13.200
# 9               Austria       9.400
# 10           Azerbaijan      18.300

# %%
# Add new Column
stats['MyCalc'] = stats['Birth Rate'] * stats['Internet']
stats.head()
# Out:
#                 Country Code  Birth Rate  Internet               Income  \
# 0                 Aruba  ABW      10.244      78.9          High income
# 1           Afghanistan  AFG      35.253       5.9           Low income
# 2                Angola  AGO      45.985      19.1  Upper middle income
# 3               Albania  ALB      12.877      57.2  Upper middle income
# 4  United Arab Emirates  ARE      11.044      88.0          High income
#
#      MyCalc
# 0  808.2516
# 1  207.9927
# 2  878.3135
# 3  736.5644
# 4  971.8720

# %%
# Returns a new object with Column dropped
# stats.drop('MyCalc', 1)
stats.head()
# Out:
#                 Country Code  Birth Rate  Internet               Income  \
# 0                 Aruba  ABW      10.244      78.9          High income
# 1           Afghanistan  AFG      35.253       5.9           Low income
# 2                Angola  AGO      45.985      19.1  Upper middle income
# 3               Albania  ALB      12.877      57.2  Upper middle income
# 4  United Arab Emirates  ARE      11.044      88.0          High income
#
#      MyCalc
# 0  808.2516
# 1  207.9927
# 2  878.3135
# 3  736.5644
# 4  971.8720

# %%
# Filter rows that have less than 2 Internet users
stats[stats['Internet'] < 2]
# Out:
#           Country Code  Birth Rate  Internet               Income   MyCalc
# 11        Burundi  BDI      44.151       1.3           Low income  57.3963
# 52        Eritrea  ERI      34.800       0.9           Low income  31.3200
# 55       Ethiopia  ETH      32.925       1.9           Low income  62.5575
# 64         Guinea  GIN      37.337       1.6           Low income  59.7392
# 117       Myanmar  MMR      18.119       1.6  Lower middle income  28.9904
# 127         Niger  NER      49.661       1.7           Low income  84.4237
# 154  Sierra Leone  SLE      36.729       1.7           Low income  62.4393
# 156       Somalia  SOM      43.891       1.5           Low income  65.8365
# 172   Timor-Leste  TLS      35.755       1.1  Lower middle income  39.3305

# %%
# Filter by two boolean filters - use bitwise operator "&" instead of "and"
stats[(stats['Internet'] < 2) & (stats['Birth Rate'] > 40)]
# Out:
#      Country Code  Birth Rate  Internet      Income   MyCalc
# 11   Burundi  BDI      44.151       1.3  Low income  57.3963
# 127    Niger  NER      49.661       1.7  Low income  84.4237
# 156  Somalia  SOM      43.891       1.5  Low income  65.8365

# %%
# Get unique values from column
stats['Income'].unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
# .iat counts through any list or matrix
stats.iat[0,1]
# Out:
# 'ABW'

# %%
# .at counts through the explicit index of the row
stats.at[0, 'Country']
# Out:
# 'Aruba'

# %%
# Increase width of charts
plt.rcParams['figure.figsize'] = 8,4

# Using Seaborn Distribution
vis1 = sns.distplot(stats['Internet'], bins=30)

# %%
# Seaborn Boxplot
vis2 = sns.boxplot(data=stats, x="Income", y="Birth Rate")

# %%
vis3 = sns.lmplot(data=stats, x="Internet", y="Birth Rate", fit_reg=False, hue="Income", size=10)
